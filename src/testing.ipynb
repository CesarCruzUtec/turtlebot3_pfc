# %%
import numpy as np
b=np.array([3,4,1])
np.linalg.norm(b[0:-1])
# Out:
# 5.0

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

fig = plt.figure(figsize=(12,6))
gs1 = GridSpec(3, 2, wspace=0.15, hspace=0.1)
ax1 = fig.add_subplot(gs1[:, 0])
ax2 = fig.add_subplot(gs1[0, 1])
ax3 = fig.add_subplot(gs1[1, 1], sharex=ax2)
ax4 = fig.add_subplot(gs1[2, 1], sharex=ax2)
ax1.set_xlim(-1.5, 1.5), ax1.set_ylim(-1.5, 1.5)
ax1.grid(), ax2.grid(), ax3.grid(), ax4.grid()
ax1.set_xlabel('x(m)'), ax1.set_ylabel('y(m)')
ax2.set_ylabel('x(m)'), ax3.set_ylabel('y(m)'), ax4.set_ylabel('theta(rad)')
ax4.set_xlabel('time(s)')
ax2.tick_params(labelbottom=False)
ax3.tick_params(labelbottom=False)
plt.show()

# %%
astr = "hola"
astr == "hola"
# Out:
# True
